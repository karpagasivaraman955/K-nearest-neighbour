# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv("train.csv")
dataset
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
X = dataset.iloc[:, [1, 2]].values
y = dataset.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state=0)

# %%
k = 3 # You can adjust the value of k
knn = KNeighborsClassifier(n_neighbors=k)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.25

# %%
correct_predictions = 0
wrong_predictions = 0
for i in range(len(y_test)):
  if y_test[i] == y_pred[i]:
    print(f"Correct prediction: Predicted {y_pred[i]}, Actual {y_test[i]}")
    correct_predictions += 1
  else:
    print(f"Wrong prediction: Predicted {y_pred[i]}, Actual {y_test[i]}")
    wrong_predictions += 1


print(f"\nTotal correct predictions: {correct_predictions}")
print(f"Total wrong predictions: {wrong_predictions}")
# Out:
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 3
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 1, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 3
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 3, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 3, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 1, Actual 1
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 3, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 3, Actual 1
# Correct prediction: Predicted 2, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 2, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 2, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 1, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 3, Actual 2
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 2, Actual 3
# Correct prediction: Predicted 2, Actual 2
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 1, Actual 3
# Correct prediction: Predicted 2, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 3, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 2, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 1, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 3, Actual 2
# Correct prediction: Predicted 1, Actual 1
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 3, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 3, Actual 1
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 2, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 2, Actual 2
# Correct prediction: Predicted 1, Actual 1
# Correct prediction: Predicted 2, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 1
# Correct prediction: Predicted 1, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 1, Actual 1
# Correct prediction: Predicted 2, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 3, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 0
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 3, Actual 2
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 0
# Wrong prediction: Predicted 1, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 2, Actual 3
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 3, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 2, Actual 0
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 2, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 3, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 2
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 1, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 1, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 3, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 3, Actual 1
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 1, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 3, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 2, Actual 0
# Wrong prediction: Predicted 3, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 1, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 2, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 1, Actual 2
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 2, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 2, Actual 3
# Wrong prediction: Predicted 3, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 1, Actual 3
# Wrong prediction: Predicted 1, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 3, Actual 2
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 3, Actual 1
# Correct prediction: Predicted 1, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 3, Actual 1
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Wrong prediction: Predicted 3, Actual 0
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 3, Actual 3
# Correct prediction: Predicted 0, Actual 0
# Correct prediction: Predicted 2, Actual 2
# Wrong prediction: Predicted 0, Actual 2
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 0, Actual 1
# Wrong prediction: Predicted 3, Actual 0
# Correct prediction: Predicted 2, Actual 2
# Wrong prediction: Predicted 0, Actual 1
#
# Total correct predictions: 100
# Total wrong predictions: 300
